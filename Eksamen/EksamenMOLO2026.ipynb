# %% [markdown]
# ## Kopiérbar blok til indsættelse af billeder
#
# ### Markdown-metode
# Kopiér linjen nedenfor til en Markdown-celle og ret filnavn/størrelse efter behov:
#
# ```markdown
# <img src="images/dit_billede.png" alt="Kort beskrivelse" width="600">
# ```
#
# ### Python-metode
# Kør kodecellen nedenfor, og brug funktionen `indsæt_billede(...)` i dine svar.

# %% [markdown]
# # Eksamen 2026 - Modellering og løsning af optimeringsproblemer
# Denne PDF, indeholder løsning, samt kode til min besvarelse af eksamensættet. Bemærk, at forklaring nogle gange fremgår som kommentarer i kodevinduerne, og andre gange explicit i teksten i opgavebesvarelsen.

# %%
from IPython.display import Image, display

def indsæt_billede(sti, bredde=600):
    """Viser et billede i notebooken.

    Parametre:
    sti: Filsti til billedet, fx 'images/figur1.png'
    bredde: Billedets bredde i pixels, fx 600
    """
    display(Image(filename=sti, width=bredde))

#indsæt_billede('tree.png', bredde=600)

# %%
# Imports
import numpy as np
import pulp as PLP
import random
import pandas as pd

# %% [markdown]
# # Opgave 1
#
# Skriv din besvarelse nedenfor.

# %% [markdown]
# ## Spørgsmål 1
#
# _Indsæt din besvarelse her._
#
# <!-- Billede, hvis relevant:
# <img src="images/dit_billede.png" alt="Kort beskrivelse" width="600">
# -->

# %%
# Beregninger/kode til dette spørgsmål kan skrives her

# %% [markdown]
# ## Spørgsmål 2
#
# _Indsæt din besvarelse her._
#
# <!-- Billede, hvis relevant:
# <img src="images/dit_billede.png" alt="Kort beskrivelse" width="600">
# -->

# %%
# Beregninger/kode til dette spørgsmål kan skrives her

# %% [markdown]
# ## Spørgsmål 3
#
# _Indsæt din besvarelse her._
#
# <!-- Billede, hvis relevant:
# <img src="images/dit_billede.png" alt="Kort beskrivelse" width="600">
# -->

# %%
# Beregninger/kode til dette spørgsmål kan skrives her

# %% [markdown]
# ## Spørgsmål 4
#
# _Indsæt din besvarelse her._
#
# <!-- Billede, hvis relevant:
# <img src="images/dit_billede.png" alt="Kort beskrivelse" width="600">
# -->

# %%
# Beregninger/kode til dette spørgsmål kan skrives her

# %% [markdown]
# \newpage
#
# # Opgave 2
#
# Skriv din besvarelse nedenfor.

# %% [markdown]
# ## Spørgsmål 1
#
# _Indsæt din besvarelse her._
#
# <!-- Billede, hvis relevant:
# <img src="images/dit_billede.png" alt="Kort beskrivelse" width="600">
# -->

# %%
# Beregninger/kode til dette spørgsmål kan skrives her

# %% [markdown]
# ## Spørgsmål 2
#
# _Indsæt din besvarelse her._
#
# <!-- Billede, hvis relevant:
# <img src="images/dit_billede.png" alt="Kort beskrivelse" width="600">
# -->

# %%
# Beregninger/kode til dette spørgsmål kan skrives her

# %% [markdown]
# ## Spørgsmål 3
#
# _Indsæt din besvarelse her._
#
# <!-- Billede, hvis relevant:
# <img src="images/dit_billede.png" alt="Kort beskrivelse" width="600">
# -->

# %%
# Beregninger/kode til dette spørgsmål kan skrives her

# %% [markdown]
# ## Spørgsmål 4
#
# _Indsæt din besvarelse her._
#
# <!-- Billede, hvis relevant:
# <img src="images/dit_billede.png" alt="Kort beskrivelse" width="600">
# -->

# %%
# Beregninger/kode til dette spørgsmål kan skrives her

# %% [markdown]
# \newpage
#
# # Opgave 3
#
# Skriv din besvarelse nedenfor.

# %% [markdown]
# ## Spørgsmål 1
#
# _Indsæt din besvarelse her._
#
# <!-- Billede, hvis relevant:
# <img src="images/dit_billede.png" alt="Kort beskrivelse" width="600">
# -->

# %%
# Beregninger/kode til dette spørgsmål kan skrives her

# %% [markdown]
# ## Spørgsmål 2
#
# _Indsæt din besvarelse her._
#
# <!-- Billede, hvis relevant:
# <img src="images/dit_billede.png" alt="Kort beskrivelse" width="600">
# -->

# %%
# Beregninger/kode til dette spørgsmål kan skrives her

# %% [markdown]
# ## Spørgsmål 3
#
# _Indsæt din besvarelse her._
#
# <!-- Billede, hvis relevant:
# <img src="images/dit_billede.png" alt="Kort beskrivelse" width="600">
# -->

# %%
# %%sql

# %%
# Beregninger/kode til dette spørgsmål kan skrives her

# %% [markdown]
# ## Spørgsmål 4
#
# _Indsæt din besvarelse her._
#
# <!-- Billede, hvis relevant:
# <img src="images/dit_billede.png" alt="Kort beskrivelse" width="600">
# -->

# %%
# Beregninger/kode til dette spørgsmål kan skrives her

# %% [markdown]
# \newpage
#
# # Opgave 4
#
# Skriv din besvarelse nedenfor.

# %% [markdown]
# ## Spørgsmål 1
#
# _Indsæt din besvarelse her._
#
# <!-- Billede, hvis relevant:
# <img src="images/dit_billede.png" alt="Kort beskrivelse" width="600">
# -->

# %%
# Beregninger/kode til dette spørgsmål kan skrives her

# %% [markdown]
# ## Spørgsmål 2
#
# _Indsæt din besvarelse her._
#
# <!-- Billede, hvis relevant:
# <img src="images/dit_billede.png" alt="Kort beskrivelse" width="600">
# -->

# %%
# Beregninger/kode til dette spørgsmål kan skrives her

# %% [markdown]
# ## Spørgsmål 3
#
# _Indsæt din besvarelse her._
#
# <!-- Billede, hvis relevant:
# <img src="images/dit_billede.png" alt="Kort beskrivelse" width="600">
# -->

# %%
# Beregninger/kode til dette spørgsmål kan skrives her

# %% [markdown]
# ## Spørgsmål 4
#
# _Indsæt din besvarelse her._
#
# <!-- Billede, hvis relevant:
# <img src="images/dit_billede.png" alt="Kort beskrivelse" width="600">
# -->

# %%
# Beregninger/kode til dette spørgsmål kan skrives her
